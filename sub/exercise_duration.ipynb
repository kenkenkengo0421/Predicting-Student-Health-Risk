# %% [markdown]
# # 運動時間

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style
import seaborn as sns
import numpy as np
from my_plot import Hist, sns_Hist, sns_kde

# %%
df = pd.read_csv("../data/train.csv")

# %%
df
# Out:
#             id health_condition  sleep_duration  heart_rate    bmi  \
# 0            0        unhealthy            5.22        70.6  25.66
# 1            1          at-risk            5.53        71.3  25.84
# 2            2        unhealthy            5.29        75.4  24.54
# 3            3        unhealthy            4.70        77.2  23.13
# 4            4          at-risk            7.23        73.4  28.44
# ...        ...              ...             ...         ...    ...
# 690083  690083          at-risk            6.31        69.7  24.11
# 690084  690084          at-risk            5.78        54.0  26.36
# 690085  690085              fit            7.64        85.7  21.91
# 690086  690086          at-risk            6.74        73.0  18.73
# 690087  690087          at-risk            5.55        69.3  24.38
#
#         calorie_expenditure  step_count  exercise_duration  water_intake  \
# 0                    2174.0      1326.0               19.8          1.86
# ...

# %%
df['exercise_duration']
# Out:
# 0         19.8
# 1         49.9
# 2         38.1
# 3         59.9
# 4         46.0
#           ...
# 690083    30.8
# 690084    52.4
# 690085    41.3
# 690086    56.6
# 690087    47.9
# Name: exercise_duration, Length: 690088, dtype: float64

# %%
matplotlib.style.use('bmh')
print("運動時間")
Hist(data=df,column_name='exercise_duration',figsize=(20, 10),step=5)
# Out:
# 運動時間

# %%
sns_Hist(data=df,x='exercise_duration' ,hue='health_condition',figsize=((20, 10)),step=5)

# %%
sns_kde(data=df,x='exercise_duration',hue='health_condition',figsize=((20, 10)),step=5)

# %% [markdown]
# * fit（紫）: 健康的な状態
# * at-risk（赤）: リスクあり（予備軍）
# * unhealthy（水色）: 不健康な状態
#
# ### 目的・年代別の運動時間の目安健康維持(ネット調べ)
#
# * 生活習慣病の予防目安：**1日20〜30分**（週150分）の中強度運動。
# * 内容：少し息が弾み、汗をかく程度の早歩きやサイクリング。
#
# ### グラフからわかること
#
# * 40時間以上運動者は健康的な傾向
