# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style
import seaborn as sns

# %%
df = pd.read_csv("../data/train.csv")

# %%
df
# Out:
#             id health_condition  sleep_duration  heart_rate    bmi  \
# 0            0        unhealthy            5.22        70.6  25.66
# 1            1          at-risk            5.53        71.3  25.84
# 2            2        unhealthy            5.29        75.4  24.54
# 3            3        unhealthy            4.70        77.2  23.13
# 4            4          at-risk            7.23        73.4  28.44
# ...        ...              ...             ...         ...    ...
# 690083  690083          at-risk            6.31        69.7  24.11
# 690084  690084          at-risk            5.78        54.0  26.36
# 690085  690085              fit            7.64        85.7  21.91
# 690086  690086          at-risk            6.74        73.0  18.73
# 690087  690087          at-risk            5.55        69.3  24.38
#
#         calorie_expenditure  step_count  exercise_duration  water_intake  \
# 0                    2174.0      1326.0               19.8          1.86
# ...

# %%
df['heart_rate']
# Out:
# 0         70.6
# 1         71.3
# 2         75.4
# 3         77.2
# 4         73.4
#           ...
# 690083    69.7
# 690084    54.0
# 690085    85.7
# 690086    73.0
# 690087    69.3
# Name: heart_rate, Length: 690088, dtype: float64

# %%
matplotlib.style.use('bmh')
print("全体の心拍数")
plt.figure(figsize=(10, 10))
plt.hist(df['heart_rate'].dropna(), bins=30,edgecolor='white')
plt.title("heart_rate")
plt.show()
# Out:
# 全体の心拍数

# %% [markdown]
# * 心拍数が多いピークゾーンは70から80くらい。
# それくらいを基準にする

# %%
plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='heart_rate', hue='health_condition', multiple='stack')
plt.xticks()
plt.show()

# %% [markdown]
# * fit（紫）: 健康的な状態
# * at-risk（赤）: リスクあり（予備軍）
# * unhealthy（水色）: 不健康な状態

# %%
plt.figure(figsize=(10, 5))
sns.kdeplot(data=df, x='heart_rate', hue='health_condition', fill=True, common_norm=False)
plt.title('')
plt.show()

# %% [markdown]
# * 心拍数はあまり関連性がなさそう
