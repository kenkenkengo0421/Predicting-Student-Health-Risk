# %% [markdown]
# # 水分摂取量

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style
import seaborn as sns
import numpy as np
from my_plot import Hist, sns_Hist, sns_kde

# %%
df = pd.read_csv("../data/train.csv")

# %%
df
# Out:
#             id health_condition  sleep_duration  heart_rate    bmi  \
# 0            0        unhealthy            5.22        70.6  25.66
# 1            1          at-risk            5.53        71.3  25.84
# 2            2        unhealthy            5.29        75.4  24.54
# 3            3        unhealthy            4.70        77.2  23.13
# 4            4          at-risk            7.23        73.4  28.44
# ...        ...              ...             ...         ...    ...
# 690083  690083          at-risk            6.31        69.7  24.11
# 690084  690084          at-risk            5.78        54.0  26.36
# 690085  690085              fit            7.64        85.7  21.91
# 690086  690086          at-risk            6.74        73.0  18.73
# 690087  690087          at-risk            5.55        69.3  24.38
#
#         calorie_expenditure  step_count  exercise_duration  water_intake  \
# 0                    2174.0      1326.0               19.8          1.86
# ...

# %%
df['water_intake']
# Out:
# 0         1.86
# 1         1.26
# 2         1.60
# 3         2.02
# 4         2.25
#           ...
# 690083    3.00
# 690084    1.46
# 690085    1.57
# 690086    2.60
# 690087    1.76
# Name: water_intake, Length: 690088, dtype: float64

# %%
matplotlib.style.use('bmh')
print("水分摂取量")
Hist(data=df,column_name='water_intake',figsize=(15, 5),step=0.5)
# Out:
# 水分摂取量

# %%
sns_Hist(data=df,x='water_intake',hue='health_condition',figsize=((15, 5)),step=0.5)

# %%
sns_kde(data=df,x='water_intake',hue='health_condition',figsize=((15, 5)),step=0.5)

# %% [markdown]
# * fit（紫）: 健康的な状態
# * at-risk（赤）: リスクあり（予備軍）
# * unhealthy（水色）: 不健康な状態
#
# # 成人の水分必要量：
# * 体重 (kg) × 30 ~ 35ml
# * 体重50kgの方：約1.5L
# * 体重60kgの方：約1.8L〜2.1L
#
# このグラフからは、関連性は見つけられなかった。
